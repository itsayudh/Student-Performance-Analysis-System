# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/student_performance_datasetv1.csv")
df.head()
# Out:
#                              student_id  attendance_percentage  \
# 0  510845f3-fec3-423e-84ba-12422f4f8058                  78.11
# 1  85fe2085-7fc6-41a7-9819-9062e3f12102                  66.63
# 2  a1e6e199-b45e-408a-b633-2cc2656dab41                  98.21
# 3  ed75ac0f-5371-4900-b7fa-b59e8978a2ec                  79.88
# 4  2bcfaf42-2ff8-45b6-9975-e8f668e78fe8                  66.58
#
#    quiz_score_avg  assignment_score_avg  midterm_score  historical_gpa  \
# 0           55.80                 54.96          59.20            2.31
# 1           69.04                 64.40          69.31            3.19
# 2           60.37                 57.75          71.17            2.69
# 3           59.76                 50.62          44.16            2.34
# 4           45.49                 57.01          49.74            2.12
#
#    study_hours_per_week  participation_score  subject_difficulty_score  \
# 0                  15.7                75.80                      3.74
# ...

# %%
df.isnull().sum()
# Out:
# student_id                  0
# attendance_percentage       0
# quiz_score_avg              0
# assignment_score_avg        0
# midterm_score               0
# historical_gpa              0
# study_hours_per_week        0
# participation_score         0
# subject_difficulty_score    0
# semester_number             0
# final_score                 0
# pass_fail                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        attendance_percentage  quiz_score_avg  assignment_score_avg  \
# count            5000.000000     5000.000000           5000.000000
# mean               82.586242       64.731186             64.459905
# std                10.104653       10.420520             10.694330
# min                65.000000       36.552500             35.681250
# 25%                73.847500       57.680000             57.210000
# 50%                82.435000       64.460000             64.420000
# 75%                91.415000       71.765000             71.562500
# max                99.990000       92.892500             93.091250
#
#        midterm_score  historical_gpa  study_hours_per_week  \
# count    5000.000000     5000.000000           5000.000000
# mean       64.154969        2.951908             22.481620
# std        11.316786        0.491422              4.485954
# min        33.711250        2.000000              8.900000
# 25%        56.507500        2.600000             19.100000
# ...

# %%
##checking the outliers
import pandas as pd
import matplotlib.pyplot as plt



numerical_cols = [
    'attendance_percentage',
    'quiz_score_avg',
    'assignment_score_avg',
    'midterm_score',
    'historical_gpa',
    'study_hours_per_week',
    'participation_score',
    'subject_difficulty_score',
    'semester_number',
    'final_score'
]

for col in numerical_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower_bound) |
        (df[col] > upper_bound)
    ]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# attendance_percentage: 0 outliers
# quiz_score_avg: 0 outliers
# assignment_score_avg: 0 outliers
# midterm_score: 0 outliers
# historical_gpa: 0 outliers
# study_hours_per_week: 0 outliers
# participation_score: 0 outliers
# subject_difficulty_score: 0 outliers
# semester_number: 0 outliers
# final_score: 0 outliers

# %%
df['subject_difficulty_score']= df['subject_difficulty_score']/10

# %%
df.head()
# Out:
#                              student_id  attendance_percentage  \
# 0  510845f3-fec3-423e-84ba-12422f4f8058                  78.11
# 1  85fe2085-7fc6-41a7-9819-9062e3f12102                  66.63
# 2  a1e6e199-b45e-408a-b633-2cc2656dab41                  98.21
# 3  ed75ac0f-5371-4900-b7fa-b59e8978a2ec                  79.88
# 4  2bcfaf42-2ff8-45b6-9975-e8f668e78fe8                  66.58
#
#    quiz_score_avg  assignment_score_avg  midterm_score  historical_gpa  \
# 0           55.80                 54.96          59.20            2.31
# 1           69.04                 64.40          69.31            3.19
# 2           60.37                 57.75          71.17            2.69
# 3           59.76                 50.62          44.16            2.34
# 4           45.49                 57.01          49.74            2.12
#
#    study_hours_per_week  participation_score  subject_difficulty_score  \
# 0                  15.7                75.80                     0.374
# ...

# %%
df.to_csv("../data/processed/student_performance_datasetv2.csv", index=False)
